# %% [markdown]
# <a href="https://colab.research.google.com/github/Samridhi-Aggarwaal/EDA/blob/main/Theory_DA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **THEORY DIGITAL ASSIGNMENT**
#
# *Samridhi [21BCE3242]*
#
#
#
#
# ---
# ---

# %%
# Required libraries

import os
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# *01. Load the dataset and print the head and tail of the dataset*

# %%
# Loading dataset
data = pd.read_csv('https://raw.githubusercontent.com/salemprakash/EDA/main/Data/countymurders.csv')

# Display the first few rows of the dataset
print("Head of the dataset: ")
print(data.head())
print("\n\nTail of the dataset: ")
print(data.tail())
# Out:
# Head of the dataset:
#    rownames  arrests  countyid  density  popul  perc1019  perc2029  percblack  \
# 0         1      2.0      1001    54.05  32216     20.63     15.28      22.33
# 1         2      3.0      1001    53.66  31984     20.19     15.55      22.07
# 2         3      2.0      1001    53.75  32036     19.66     15.73      21.80
# 3         4      7.0      1001    53.78  32056     19.10     15.88      21.53
# 4         5      3.0      1001    53.91  32128     18.54     15.92      21.26
#
#    percmale  rpcincmaint  ...  rpcunemins  year  murders  murdrate  \
# 0     40.25       167.67  ...       29.16  1980        2  0.620810
# 1     40.36       167.99  ...       43.92  1981        1  0.312656
# 2     40.42       166.63  ...       71.41  1982        3  0.936446
# 3     40.47       176.53  ...       72.22  1983        7  2.183679
# 4     40.51       166.25  ...       40.36  1984        2  0.622510
#
#    arrestrate  statefips  countyfips  execs    lpopul  execrate
# 0    0.620810          1           1      0  10.38022       0.0
# 1    0.937969          1           1      0  10.37299       0.0
# 2    0.624298          1           1      0  10.37462       0.0
# 3    2.183679          1           1      0  10.37524       0.0
# 4    0.933765          1           1      0  10.37748       0.0
#
# [5 rows x 21 columns]
#
#
# Tail of the dataset:
#        rownames  arrests  countyid   density  popul  perc1019   perc2029  \
# 37344     37345      0.0     56045  2.680000   6430  16.35000  10.260000
# 37345     37346      1.0     56045  2.708031   6493  16.67950   9.610350
# 37346     37347      0.0     56045  2.736391   6561  16.79622   9.510745
# 37347     37348      0.0     56045  2.730135   6546  17.01803   9.563092
# 37348     37349      0.0     56045  2.733472   6554  16.90571   9.642966
#
#        percblack  percmale  rpcincmaint  ...  rpcunemins  year  murders  \
# 37344   0.060000  42.67000       95.540  ...      54.190  1992        0
# 37345   0.077006  50.13091      107.260  ...      42.904  1993        0
# 37346   0.030483  50.16004       98.550  ...      39.150  1994        0
# 37347   0.076383  50.18332      106.928  ...      38.048  1995        0
# 37348   0.076289  50.13732      116.116  ...      40.194  1996        0
#
#        murdrate  arrestrate  statefips  countyfips  execs    lpopul  execrate
# 37344       0.0     0.00000         56          45      0  8.768730       0.0
# 37345       0.0     1.54012         56          45      0  8.778480       0.0
# 37346       0.0     0.00000         56          45      0  8.788898       0.0
# 37347       0.0     0.00000         56          45      0  8.786610       0.0
# 37348       0.0     0.00000         56          45      0  8.787830       0.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ---
#
#
#
# *2. Description of the dataset*

# %%
# 1. Dataset description
data['murders'].value_counts()
# Out:
# murders
# 0       15651
# 1        6637
# 2        3898
# 3        2286
# 4        1603
#         ...
# 1348        1
# 1416        1
# 1500        1
# 139         1
# 252         1
# Name: count, Length: 356, dtype: int64

# %%
print("Dataset description")
data.describe()
# Out:
# Dataset description
#            rownames       arrests      countyid       density         popul  \
# count  37349.000000  36845.000000  37349.000000  37349.000000  3.734900e+04
# mean   18675.000000      6.782250  32921.927173    252.241067  8.934354e+04
# std    10781.871939     50.128657  15528.352966   1663.768484  2.718545e+05
# min        1.000000      0.000000   1001.000000      0.050000  8.500000e+01
# 25%     9338.000000      0.000000  20105.000000     17.681580  1.314400e+04
# 50%    18675.000000      1.000000  36065.000000     44.240000  2.879200e+04
# 75%    28012.000000      3.000000  48049.000000    106.600000  6.648000e+04
# max    37349.000000   2391.000000  56045.000000  54058.770000  9.127751e+06
#
#            perc1019      perc2029     percblack      percmale   rpcincmaint  \
# count  37349.000000  37349.000000  37349.000000  37349.000000  37346.000000
# mean      15.582640     14.584615      7.823194     43.350958    165.450844
# std        1.973399      3.696407     13.287067      3.717612     97.488961
# min        7.080000      5.617244      0.000000     35.150000      5.490000
# 25%       14.320000     12.301700      0.200000     40.900000     96.250000
# 50%       15.420000     14.270000      1.450000     41.810000    145.147500
# 75%       16.730000     16.200000      8.740000     45.870000    209.880000
# max       30.484580     40.520000     86.279340     78.040000   1306.496000
#
#        ...    rpcunemins          year       murders      murdrate  \
# count  ...  37346.000000  37349.000000  37349.000000  37349.000000
# mean   ...     70.557953   1988.000000      7.286915      0.508202
# std    ...     52.909393      4.899045     47.217586      0.851044
# min    ...      0.000000   1980.000000      0.000000      0.000000
# 25%    ...     35.200000   1984.000000      0.000000      0.000000
# 50%    ...     57.100000   1988.000000      1.000000      0.241044
# 75%    ...     89.958000   1992.000000      3.000000      0.735294
# max    ...    642.730000   1996.000000   1944.000000     39.840640
#
#          arrestrate     statefips    countyfips         execs        lpopul  \
# count  36845.000000  37349.000000  37349.000000  37349.000000  37349.000000
# mean       0.511486     32.821575    100.352299      0.006854     10.347289
# std        1.232562     15.503684    107.942699      0.112448      1.327145
# min        0.000000      1.000000      1.000000      0.000000      4.442651
# 25%        0.000000     20.000000     33.000000      0.000000      9.483721
# 50%        0.163677     36.000000     75.000000      0.000000     10.267850
# 75%        0.701715     48.000000    127.000000      0.000000     11.104660
# max      148.658400     56.000000    840.000000      7.000000     16.026830
#
#            execrate
# count  37349.000000
# mean       0.001042
# std        0.029068
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        2.388916
#
# [8 rows x 21 columns]

# %%
stacked = data.stack()
stacked
# Out:
# 0      rownames          1.00000
#        arrests           2.00000
#        countyid       1001.00000
#        density          54.05000
#        popul         32216.00000
#                         ...
# 37348  statefips        56.00000
#        countyfips       45.00000
#        execs             0.00000
#        lpopul            8.78783
#        execrate          0.00000
# Length: 783312, dtype: float64

# %%
stacked.unstack()
# Out:
#        rownames  arrests  countyid    density    popul  perc1019   perc2029  \
# 0           1.0      2.0    1001.0  54.050000  32216.0  20.63000  15.280000
# 1           2.0      3.0    1001.0  53.660000  31984.0  20.19000  15.550000
# 2           3.0      2.0    1001.0  53.750000  32036.0  19.66000  15.730000
# 3           4.0      7.0    1001.0  53.780000  32056.0  19.10000  15.880000
# 4           5.0      3.0    1001.0  53.910000  32128.0  18.54000  15.920000
# ...         ...      ...       ...        ...      ...       ...        ...
# 37344   37345.0      0.0   56045.0   2.680000   6430.0  16.35000  10.260000
# 37345   37346.0      1.0   56045.0   2.708031   6493.0  16.67950   9.610350
# 37346   37347.0      0.0   56045.0   2.736391   6561.0  16.79622   9.510745
# 37347   37348.0      0.0   56045.0   2.730135   6546.0  17.01803   9.563092
# 37348   37349.0      0.0   56045.0   2.733472   6554.0  16.90571   9.642966
#
#        percblack  percmale  rpcincmaint  ...  rpcunemins    year  murders  \
# 0      22.330000  40.25000      167.670  ...      29.160  1980.0      2.0
# 1      22.070000  40.36000      167.990  ...      43.920  1981.0      1.0
# 2      21.800000  40.42000      166.630  ...      71.410  1982.0      3.0
# 3      21.530000  40.47000      176.530  ...      72.220  1983.0      7.0
# 4      21.260000  40.51000      166.250  ...      40.360  1984.0      2.0
# ...          ...       ...          ...  ...         ...     ...      ...
# 37344   0.060000  42.67000       95.540  ...      54.190  1992.0      0.0
# 37345   0.077006  50.13091      107.260  ...      42.904  1993.0      0.0
# 37346   0.030483  50.16004       98.550  ...      39.150  1994.0      0.0
# 37347   0.076383  50.18332      106.928  ...      38.048  1995.0      0.0
# 37348   0.076289  50.13732      116.116  ...      40.194  1996.0      0.0
#
#        murdrate  arrestrate  statefips  countyfips  execs     lpopul  execrate
# 0      0.620810    0.620810        1.0         1.0    0.0  10.380220       0.0
# 1      0.312656    0.937969        1.0         1.0    0.0  10.372990       0.0
# 2      0.936446    0.624298        1.0         1.0    0.0  10.374620       0.0
# 3      2.183679    2.183679        1.0         1.0    0.0  10.375240       0.0
# 4      0.622510    0.933765        1.0         1.0    0.0  10.377480       0.0
# ...         ...         ...        ...         ...    ...        ...       ...
# 37344  0.000000    0.000000       56.0        45.0    0.0   8.768730       0.0
# 37345  0.000000    1.540120       56.0        45.0    0.0   8.778480       0.0
# 37346  0.000000    0.000000       56.0        45.0    0.0   8.788898       0.0
# 37347  0.000000    0.000000       56.0        45.0    0.0   8.786610       0.0
# 37348  0.000000    0.000000       56.0        45.0    0.0   8.787830       0.0
#
# [37349 rows x 21 columns]

# %%
# 2. Number of rows and columns
num_rows, num_columns = data.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")

# 3. Header/attribute names in the dataset
header_names = data.columns.tolist()
print("\nAttribute names: ", header_names)
# Out:
# Number of rows: 37349
# Number of columns: 21
#
# Attribute names:  ['rownames', 'arrests', 'countyid', 'density', 'popul', 'perc1019', 'perc2029', 'percblack', 'percmale', 'rpcincmaint', 'rpcpersinc', 'rpcunemins', 'year', 'murders', 'murdrate', 'arrestrate', 'statefips', 'countyfips', 'execs', 'lpopul', 'execrate']

# %%
# 4. Structure of the dataset (data types of each column)
data_structure = data.dtypes
print("Structure of the dataset (Data types):\n", data_structure)
# Out:
# Structure of the dataset (Data types):
#  rownames         int64
# arrests        float64
# countyid         int64
# density        float64
# popul            int64
# perc1019       float64
# perc2029       float64
# percblack      float64
# percmale       float64
# rpcincmaint    float64
# rpcpersinc     float64
# rpcunemins     float64
# year             int64
# murders          int64
# murdrate       float64
# arrestrate     float64
# statefips        int64
# countyfips       int64
# execs            int64
# lpopul         float64
# execrate       float64
# dtype: object

# %%
# 5. Summarization of the dataset
data_summary = data.describe(include='all')
print("\nSummarization of the dataset:\n", data_summary)
# Out:
# Summarization of the dataset:
#             rownames       arrests      countyid       density         popul  \
# count  37349.000000  36845.000000  37349.000000  37349.000000  3.734900e+04
# mean   18675.000000      6.782250  32921.927173    252.241067  8.934354e+04
# std    10781.871939     50.128657  15528.352966   1663.768484  2.718545e+05
# min        1.000000      0.000000   1001.000000      0.050000  8.500000e+01
# 25%     9338.000000      0.000000  20105.000000     17.681580  1.314400e+04
# 50%    18675.000000      1.000000  36065.000000     44.240000  2.879200e+04
# 75%    28012.000000      3.000000  48049.000000    106.600000  6.648000e+04
# max    37349.000000   2391.000000  56045.000000  54058.770000  9.127751e+06
#
#            perc1019      perc2029     percblack      percmale   rpcincmaint  \
# count  37349.000000  37349.000000  37349.000000  37349.000000  37346.000000
# mean      15.582640     14.584615      7.823194     43.350958    165.450844
# std        1.973399      3.696407     13.287067      3.717612     97.488961
# min        7.080000      5.617244      0.000000     35.150000      5.490000
# 25%       14.320000     12.301700      0.200000     40.900000     96.250000
# 50%       15.420000     14.270000      1.450000     41.810000    145.147500
# 75%       16.730000     16.200000      8.740000     45.870000    209.880000
# max       30.484580     40.520000     86.279340     78.040000   1306.496000
#
#        ...    rpcunemins          year       murders      murdrate  \
# count  ...  37346.000000  37349.000000  37349.000000  37349.000000
# mean   ...     70.557953   1988.000000      7.286915      0.508202
# std    ...     52.909393      4.899045     47.217586      0.851044
# min    ...      0.000000   1980.000000      0.000000      0.000000
# 25%    ...     35.200000   1984.000000      0.000000      0.000000
# 50%    ...     57.100000   1988.000000      1.000000      0.241044
# 75%    ...     89.958000   1992.000000      3.000000      0.735294
# max    ...    642.730000   1996.000000   1944.000000     39.840640
#
#          arrestrate     statefips    countyfips         execs        lpopul  \
# count  36845.000000  37349.000000  37349.000000  37349.000000  37349.000000
# mean       0.511486     32.821575    100.352299      0.006854     10.347289
# std        1.232562     15.503684    107.942699      0.112448      1.327145
# min        0.000000      1.000000      1.000000      0.000000      4.442651
# 25%        0.000000     20.000000     33.000000      0.000000      9.483721
# 50%        0.163677     36.000000     75.000000      0.000000     10.267850
# 75%        0.701715     48.000000    127.000000      0.000000     11.104660
# max      148.658400     56.000000    840.000000      7.000000     16.026830
#
#            execrate
# count  37349.000000
# mean       0.001042
# std        0.029068
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        2.388916
#
# [8 rows x 21 columns]

# %%
# 6. Checking datatypes of each column
data.dtypes
# Out:
# rownames         int64
# arrests        float64
# countyid         int64
# density        float64
# popul            int64
# perc1019       float64
# perc2029       float64
# percblack      float64
# percmale       float64
# rpcincmaint    float64
# rpcpersinc     float64
# rpcunemins     float64
# year             int64
# murders          int64
# murdrate       float64
# arrestrate     float64
# statefips        int64
# countyfips       int64
# execs            int64
# lpopul         float64
# execrate       float64
# dtype: object

# %% [markdown]
# ---
#
#
#
# *3. Data Cleaning and Statistical Analysis*

# %%
# 1. Checking for duplicate values
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 37344    False
# 37345    False
# 37346    False
# 37347    False
# 37348    False
# Length: 37349, dtype: bool

# %%
# Total duplicated values
data.duplicated().sum()
# Out:
# 0

# %%
# 2. Checking for missing values in each row
missing_data = data.isnull().sum()
print("Missing or NA values in the dataset:\n", missing_data)
# Out:
# Missing or NA values in the dataset:
#  rownames         0
# arrests        504
# countyid         0
# density          0
# popul            0
# perc1019         0
# perc2029         0
# percblack        0
# percmale         0
# rpcincmaint      3
# rpcpersinc       3
# rpcunemins       3
# year             0
# murders          0
# murdrate         0
# arrestrate     504
# statefips        0
# countyfips       0
# execs            0
# lpopul           0
# execrate         0
# dtype: int64

# %%
print("Total number of missing or NA values in the dataset:",data.isnull().sum().sum())
# Out:
# Total number of missing or NA values in the dataset: 1017

# %%
data.count()
# Out:
# rownames       37349
# arrests        36845
# countyid       37349
# density        37349
# popul          37349
# perc1019       37349
# perc2029       37349
# percblack      37349
# percmale       37349
# rpcincmaint    37346
# rpcpersinc     37346
# rpcunemins     37346
# year           37349
# murders        37349
# murdrate       37349
# arrestrate     36845
# statefips      37349
# countyfips     37349
# execs          37349
# lpopul         37349
# execrate       37349
# dtype: int64

# %%
# 3. Handling missing values
handling_data = data.fillna(0)
print("\nDataset after replacing missing values with 0:\n", handling_data)
# Out:
# Dataset after replacing missing values with 0:
#         rownames  arrests  countyid    density  popul  perc1019   perc2029  \
# 0             1      2.0      1001  54.050000  32216  20.63000  15.280000
# 1             2      3.0      1001  53.660000  31984  20.19000  15.550000
# 2             3      2.0      1001  53.750000  32036  19.66000  15.730000
# 3             4      7.0      1001  53.780000  32056  19.10000  15.880000
# 4             5      3.0      1001  53.910000  32128  18.54000  15.920000
# ...         ...      ...       ...        ...    ...       ...        ...
# 37344     37345      0.0     56045   2.680000   6430  16.35000  10.260000
# 37345     37346      1.0     56045   2.708031   6493  16.67950   9.610350
# 37346     37347      0.0     56045   2.736391   6561  16.79622   9.510745
# 37347     37348      0.0     56045   2.730135   6546  17.01803   9.563092
# 37348     37349      0.0     56045   2.733472   6554  16.90571   9.642966
#
#        percblack  percmale  rpcincmaint  ...  rpcunemins  year  murders  \
# 0      22.330000  40.25000      167.670  ...      29.160  1980        2
# 1      22.070000  40.36000      167.990  ...      43.920  1981        1
# 2      21.800000  40.42000      166.630  ...      71.410  1982        3
# 3      21.530000  40.47000      176.530  ...      72.220  1983        7
# 4      21.260000  40.51000      166.250  ...      40.360  1984        2
# ...          ...       ...          ...  ...         ...   ...      ...
# 37344   0.060000  42.67000       95.540  ...      54.190  1992        0
# 37345   0.077006  50.13091      107.260  ...      42.904  1993        0
# 37346   0.030483  50.16004       98.550  ...      39.150  1994        0
# 37347   0.076383  50.18332      106.928  ...      38.048  1995        0
# 37348   0.076289  50.13732      116.116  ...      40.194  1996        0
#
#        murdrate  arrestrate  statefips  countyfips  execs     lpopul  execrate
# 0      0.620810    0.620810          1           1      0  10.380220       0.0
# 1      0.312656    0.937969          1           1      0  10.372990       0.0
# 2      0.936446    0.624298          1           1      0  10.374620       0.0
# 3      2.183679    2.183679          1           1      0  10.375240       0.0
# 4      0.622510    0.933765          1           1      0  10.377480       0.0
# ...         ...         ...        ...         ...    ...        ...       ...
# 37344  0.000000    0.000000         56          45      0   8.768730       0.0
# 37345  0.000000    1.540120         56          45      0   8.778480       0.0
# 37346  0.000000    0.000000         56          45      0   8.788898       0.0
# 37347  0.000000    0.000000         56          45      0   8.786610       0.0
# 37348  0.000000    0.000000         56          45      0   8.787830       0.0
#
# [37349 rows x 21 columns]

# %%
# Filling missing values with mean
data.fillna(data.mean())
# Out:
#        rownames  arrests  countyid    density  popul  perc1019   perc2029  \
# 0             1      2.0      1001  54.050000  32216  20.63000  15.280000
# 1             2      3.0      1001  53.660000  31984  20.19000  15.550000
# 2             3      2.0      1001  53.750000  32036  19.66000  15.730000
# 3             4      7.0      1001  53.780000  32056  19.10000  15.880000
# 4             5      3.0      1001  53.910000  32128  18.54000  15.920000
# ...         ...      ...       ...        ...    ...       ...        ...
# 37344     37345      0.0     56045   2.680000   6430  16.35000  10.260000
# 37345     37346      1.0     56045   2.708031   6493  16.67950   9.610350
# 37346     37347      0.0     56045   2.736391   6561  16.79622   9.510745
# 37347     37348      0.0     56045   2.730135   6546  17.01803   9.563092
# 37348     37349      0.0     56045   2.733472   6554  16.90571   9.642966
#
#        percblack  percmale  rpcincmaint  ...  rpcunemins  year  murders  \
# 0      22.330000  40.25000      167.670  ...      29.160  1980        2
# 1      22.070000  40.36000      167.990  ...      43.920  1981        1
# 2      21.800000  40.42000      166.630  ...      71.410  1982        3
# 3      21.530000  40.47000      176.530  ...      72.220  1983        7
# 4      21.260000  40.51000      166.250  ...      40.360  1984        2
# ...          ...       ...          ...  ...         ...   ...      ...
# 37344   0.060000  42.67000       95.540  ...      54.190  1992        0
# 37345   0.077006  50.13091      107.260  ...      42.904  1993        0
# 37346   0.030483  50.16004       98.550  ...      39.150  1994        0
# 37347   0.076383  50.18332      106.928  ...      38.048  1995        0
# 37348   0.076289  50.13732      116.116  ...      40.194  1996        0
#
#        murdrate  arrestrate  statefips  countyfips  execs     lpopul  execrate
# 0      0.620810    0.620810          1           1      0  10.380220       0.0
# 1      0.312656    0.937969          1           1      0  10.372990       0.0
# 2      0.936446    0.624298          1           1      0  10.374620       0.0
# 3      2.183679    2.183679          1           1      0  10.375240       0.0
# 4      0.622510    0.933765          1           1      0  10.377480       0.0
# ...         ...         ...        ...         ...    ...        ...       ...
# 37344  0.000000    0.000000         56          45      0   8.768730       0.0
# 37345  0.000000    1.540120         56          45      0   8.778480       0.0
# 37346  0.000000    0.000000         56          45      0   8.788898       0.0
# 37347  0.000000    0.000000         56          45      0   8.786610       0.0
# 37348  0.000000    0.000000         56          45      0   8.787830       0.0
#
# [37349 rows x 21 columns]

# %%
# Forward filling of missing values
data.fillna(method='ffill')
# Out:
# <ipython-input-20-7716f939c2be>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill')
#        rownames  arrests  countyid    density  popul  perc1019   perc2029  \
# 0             1      2.0      1001  54.050000  32216  20.63000  15.280000
# 1             2      3.0      1001  53.660000  31984  20.19000  15.550000
# 2             3      2.0      1001  53.750000  32036  19.66000  15.730000
# 3             4      7.0      1001  53.780000  32056  19.10000  15.880000
# 4             5      3.0      1001  53.910000  32128  18.54000  15.920000
# ...         ...      ...       ...        ...    ...       ...        ...
# 37344     37345      0.0     56045   2.680000   6430  16.35000  10.260000
# 37345     37346      1.0     56045   2.708031   6493  16.67950   9.610350
# 37346     37347      0.0     56045   2.736391   6561  16.79622   9.510745
# 37347     37348      0.0     56045   2.730135   6546  17.01803   9.563092
# 37348     37349      0.0     56045   2.733472   6554  16.90571   9.642966
#
#        percblack  percmale  rpcincmaint  ...  rpcunemins  year  murders  \
# 0      22.330000  40.25000      167.670  ...      29.160  1980        2
# 1      22.070000  40.36000      167.990  ...      43.920  1981        1
# 2      21.800000  40.42000      166.630  ...      71.410  1982        3
# 3      21.530000  40.47000      176.530  ...      72.220  1983        7
# 4      21.260000  40.51000      166.250  ...      40.360  1984        2
# ...          ...       ...          ...  ...         ...   ...      ...
# 37344   0.060000  42.67000       95.540  ...      54.190  1992        0
# 37345   0.077006  50.13091      107.260  ...      42.904  1993        0
# 37346   0.030483  50.16004       98.550  ...      39.150  1994        0
# 37347   0.076383  50.18332      106.928  ...      38.048  1995        0
# 37348   0.076289  50.13732      116.116  ...      40.194  1996        0
#
#        murdrate  arrestrate  statefips  countyfips  execs     lpopul  execrate
# 0      0.620810    0.620810          1           1      0  10.380220       0.0
# 1      0.312656    0.937969          1           1      0  10.372990       0.0
# 2      0.936446    0.624298          1           1      0  10.374620       0.0
# 3      2.183679    2.183679          1           1      0  10.375240       0.0
# 4      0.622510    0.933765          1           1      0  10.377480       0.0
# ...         ...         ...        ...         ...    ...        ...       ...
# 37344  0.000000    0.000000         56          45      0   8.768730       0.0
# 37345  0.000000    1.540120         56          45      0   8.778480       0.0
# 37346  0.000000    0.000000         56          45      0   8.788898       0.0
# 37347  0.000000    0.000000         56          45      0   8.786610       0.0
# 37348  0.000000    0.000000         56          45      0   8.787830       0.0
#
# [37349 rows x 21 columns]

# %%
# Backward filling of missing values
data.fillna(method='bfill')
# Out:
# <ipython-input-21-41282697c082>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill')
#        rownames  arrests  countyid    density  popul  perc1019   perc2029  \
# 0             1      2.0      1001  54.050000  32216  20.63000  15.280000
# 1             2      3.0      1001  53.660000  31984  20.19000  15.550000
# 2             3      2.0      1001  53.750000  32036  19.66000  15.730000
# 3             4      7.0      1001  53.780000  32056  19.10000  15.880000
# 4             5      3.0      1001  53.910000  32128  18.54000  15.920000
# ...         ...      ...       ...        ...    ...       ...        ...
# 37344     37345      0.0     56045   2.680000   6430  16.35000  10.260000
# 37345     37346      1.0     56045   2.708031   6493  16.67950   9.610350
# 37346     37347      0.0     56045   2.736391   6561  16.79622   9.510745
# 37347     37348      0.0     56045   2.730135   6546  17.01803   9.563092
# 37348     37349      0.0     56045   2.733472   6554  16.90571   9.642966
#
#        percblack  percmale  rpcincmaint  ...  rpcunemins  year  murders  \
# 0      22.330000  40.25000      167.670  ...      29.160  1980        2
# 1      22.070000  40.36000      167.990  ...      43.920  1981        1
# 2      21.800000  40.42000      166.630  ...      71.410  1982        3
# 3      21.530000  40.47000      176.530  ...      72.220  1983        7
# 4      21.260000  40.51000      166.250  ...      40.360  1984        2
# ...          ...       ...          ...  ...         ...   ...      ...
# 37344   0.060000  42.67000       95.540  ...      54.190  1992        0
# 37345   0.077006  50.13091      107.260  ...      42.904  1993        0
# 37346   0.030483  50.16004       98.550  ...      39.150  1994        0
# 37347   0.076383  50.18332      106.928  ...      38.048  1995        0
# 37348   0.076289  50.13732      116.116  ...      40.194  1996        0
#
#        murdrate  arrestrate  statefips  countyfips  execs     lpopul  execrate
# 0      0.620810    0.620810          1           1      0  10.380220       0.0
# 1      0.312656    0.937969          1           1      0  10.372990       0.0
# 2      0.936446    0.624298          1           1      0  10.374620       0.0
# 3      2.183679    2.183679          1           1      0  10.375240       0.0
# 4      0.622510    0.933765          1           1      0  10.377480       0.0
# ...         ...         ...        ...         ...    ...        ...       ...
# 37344  0.000000    0.000000         56          45      0   8.768730       0.0
# 37345  0.000000    1.540120         56          45      0   8.778480       0.0
# 37346  0.000000    0.000000         56          45      0   8.788898       0.0
# 37347  0.000000    0.000000         56          45      0   8.786610       0.0
# 37348  0.000000    0.000000         56          45      0   8.787830       0.0
#
# [37349 rows x 21 columns]

# %%
# 4. Display descriptive statistics for all the numerical data types in the dataset
desc_stats = data.describe()
print("Descriptive Statistics for all numerical data types:\n", desc_stats)
# Out:
# Descriptive Statistics for all numerical data types:
#             rownames       arrests      countyid       density         popul  \
# count  37349.000000  36845.000000  37349.000000  37349.000000  3.734900e+04
# mean   18675.000000      6.782250  32921.927173    252.241067  8.934354e+04
# std    10781.871939     50.128657  15528.352966   1663.768484  2.718545e+05
# min        1.000000      0.000000   1001.000000      0.050000  8.500000e+01
# 25%     9338.000000      0.000000  20105.000000     17.681580  1.314400e+04
# 50%    18675.000000      1.000000  36065.000000     44.240000  2.879200e+04
# 75%    28012.000000      3.000000  48049.000000    106.600000  6.648000e+04
# max    37349.000000   2391.000000  56045.000000  54058.770000  9.127751e+06
#
#            perc1019      perc2029     percblack      percmale   rpcincmaint  \
# count  37349.000000  37349.000000  37349.000000  37349.000000  37346.000000
# mean      15.582640     14.584615      7.823194     43.350958    165.450844
# std        1.973399      3.696407     13.287067      3.717612     97.488961
# min        7.080000      5.617244      0.000000     35.150000      5.490000
# 25%       14.320000     12.301700      0.200000     40.900000     96.250000
# 50%       15.420000     14.270000      1.450000     41.810000    145.147500
# 75%       16.730000     16.200000      8.740000     45.870000    209.880000
# max       30.484580     40.520000     86.279340     78.040000   1306.496000
#
#        ...    rpcunemins          year       murders      murdrate  \
# count  ...  37346.000000  37349.000000  37349.000000  37349.000000
# mean   ...     70.557953   1988.000000      7.286915      0.508202
# std    ...     52.909393      4.899045     47.217586      0.851044
# min    ...      0.000000   1980.000000      0.000000      0.000000
# 25%    ...     35.200000   1984.000000      0.000000      0.000000
# 50%    ...     57.100000   1988.000000      1.000000      0.241044
# 75%    ...     89.958000   1992.000000      3.000000      0.735294
# max    ...    642.730000   1996.000000   1944.000000     39.840640
#
#          arrestrate     statefips    countyfips         execs        lpopul  \
# count  36845.000000  37349.000000  37349.000000  37349.000000  37349.000000
# mean       0.511486     32.821575    100.352299      0.006854     10.347289
# std        1.232562     15.503684    107.942699      0.112448      1.327145
# min        0.000000      1.000000      1.000000      0.000000      4.442651
# 25%        0.000000     20.000000     33.000000      0.000000      9.483721
# 50%        0.163677     36.000000     75.000000      0.000000     10.267850
# 75%        0.701715     48.000000    127.000000      0.000000     11.104660
# max      148.658400     56.000000    840.000000      7.000000     16.026830
#
#            execrate
# count  37349.000000
# mean       0.001042
# std        0.029068
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        2.388916
#
# [8 rows x 21 columns]

# %%
# 5. Discretization and binning
pd.cut(np.random.rand(40), 5, precision=2)
# Out:
# [(0.04, 0.22], (0.41, 0.59], (0.77, 0.95], (0.41, 0.59], (0.41, 0.59], ..., (0.22, 0.41], (0.22, 0.41], (0.22, 0.41], (0.04, 0.22], (0.22, 0.41]]
# Length: 40
# Categories (5, interval[float64, right]): [(0.04, 0.22] < (0.22, 0.41] < (0.41, 0.59] <
#                                            (0.59, 0.77] < (0.77, 0.95]]

# %%
randomNumbers = np.random.rand(2000)
bins = pd.qcut(randomNumbers, 4)
bins
# Out:
# [(0.237, 0.491], (-0.0009354000000000001, 0.237], (0.491, 0.742], (0.742, 1.0], (0.237, 0.491], ..., (0.742, 1.0], (-0.0009354000000000001, 0.237], (-0.0009354000000000001, 0.237], (0.491, 0.742], (0.237, 0.491]]
# Length: 2000
# Categories (4, interval[float64, right]): [(-0.0009354000000000001, 0.237] < (0.237, 0.491] < (0.491, 0.742] <
#                                            (0.742, 1.0]]

# %%
pd.value_counts(bins)
# Out:
# <ipython-input-25-5947ffe17bfc>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(bins)
# (-0.0009354000000000001, 0.237]    500
# (0.237, 0.491]                     500
# (0.491, 0.742]                     500
# (0.742, 1.0]                       500
# Name: count, dtype: int64

# %%
# 6. Record numbers where more than 2 murders occured
Total = data["murders"]
Total[np.abs(Total) > 2]
# Out:
# 2        3
# 3        7
# 6        4
# 9        3
# 15       5
#         ..
# 37274    3
# 37275    5
# 37276    5
# 37300    3
# 37312    3
# Name: murders, Length: 11163, dtype: int64

# %%
# 7. Records where more than 3 murders occured
data[np.abs(Total) > 3]
# Out:
#        rownames  arrests  countyid   density  popul  perc1019  perc2029  \
# 3             4      7.0      1001  53.78000  32056  19.10000  15.88000
# 6             7      1.0      1001  55.18000  32888  17.68000  15.66000
# 15           16      5.0      1001  65.36304  38957  15.96889  13.33522
# 16           17      8.0      1001  67.21535  40061  15.89077  13.17491
# 17           18      4.0      1003  49.45000  78944  17.98000  14.95000
# ...         ...      ...       ...       ...    ...       ...       ...
# 37266     37267      5.0     56037   4.39000  45736  15.95000  21.32000
# 37268     37269      2.0     56037   4.07000  42472  16.10000  18.74000
# 37270     37271      5.0     56037   4.24000  44216  16.61000  16.21000
# 37275     37276      3.0     56037   3.83000  39952  18.82000  12.36000
# 37276     37277      4.0     56037   3.87000  40360  19.21000  12.05000
#
#        percblack  percmale  rpcincmaint  ...  rpcunemins  year  murders  \
# 3       21.53000  40.47000      176.530  ...      72.220  1983        7
# 6       20.72000  40.41000      151.560  ...      38.350  1986        4
# 15      20.87686  48.72552      197.456  ...      31.488  1995        5
# 16      20.97551  48.70073      192.038  ...      26.796  1996        7
# 17      15.22000  40.55000      132.430  ...      25.510  1980        4
# ...          ...       ...          ...  ...         ...   ...      ...
# 37266    0.76000  41.40000       33.120  ...     133.510  1982        5
# 37268    0.75000  40.78000       50.930  ...      70.150  1984        4
# 37270    0.76000  40.56000       62.080  ...     106.820  1986        4
# 37275    0.75000  41.56000       90.280  ...      53.580  1991        5
# 37276    0.76000  41.87000       97.680  ...      71.300  1992        5
#
#        murdrate  arrestrate  statefips  countyfips  execs    lpopul  execrate
# 3      2.183679    2.183679          1           1      0  10.37524       0.0
# 6      1.216249    0.304062          1           1      0  10.40086       0.0
# 15     1.283466    1.283466          1           1      0  10.57021       0.0
# 16     1.747335    1.996955          1           1      0  10.59816       0.0
# 17     0.506688    0.506688          1           3      0  11.27649       0.0
# ...         ...         ...        ...         ...    ...       ...       ...
# 37266  1.093231    1.093231         56          37      0  10.73064       0.0
# 37268  0.941797    0.470898         56          37      0  10.65660       0.0
# 37270  0.904650    1.130812         56          37      0  10.69684       0.0
# 37275  1.251502    0.750901         56          37      0  10.59543       0.0
# 37276  1.238850    0.991080         56          37      0  10.60559       0.0
#
# [8877 rows x 21 columns]

# %%
# 8. Cleaning fields
#Setting the missing value to mean of murders and convert the datatype to integer
murders = data['murders'].loc[data['murders'] != '?']
print(murders)
pmean = murders.astype(int).mean()
print("Mean =",pmean)
data['murders'] = data['murders'].replace('?',pmean).astype(int)
data['murders'].head(10)
# Out:
# 0        2
# 1        1
# 2        3
# 3        7
# 4        2
#         ..
# 37344    0
# 37345    0
# 37346    0
# 37347    0
# 37348    0
# Name: murders, Length: 37349, dtype: int64
# Mean = 7.286915312324292
# 0    2
# 1    1
# 2    3
# 3    7
# 4    2
# 5    2
# 6    4
# 7    1
# 8    0
# 9    3
# Name: murders, dtype: int64

# %%
# Cleaning the popul field
data[data['popul']=='?'].count()
nl=data['popul'].loc[data['popul'] !='?'].count()
nmean=nl.astype(int).mean()
data['popul'] = data['popul'].replace('?',nmean).astype(int)
data['popul'].head()
# Out:
# 0    32216
# 1    31984
# 2    32036
# 3    32056
# 4    32128
# Name: popul, dtype: int64

# %% [markdown]
# ---
#
#
#
# *4. Univariate analysis and univariate plots*

# %%
print("Univariate Analysis:")
# 1. Measure of central tendency (mean, median, mode)
murders_mean = data['murders'].mean()
murders_median = data['murders'].median()
murders_mode = data['murders'].mode()

print("\nCentral Tendency Measures of the 'murders' column:")
print(f"Mean: {murders_mean}, Median: {murders_median}, Mode: {murders_mode.values}")

# 2. Measure of dispersion (standard deviation, variance)
murders_std = data['murders'].std()
murders_variance = data['murders'].var()

print("\nDispersion Measures of the 'murders' column:")
print(f"Standard Deviation: {murders_std}, Variance: {murders_variance}")

# 3. Compute quartile ranges and IQR
murders_quartiles = data['murders'].quantile([0.25, 0.5, 0.75])
iqr = murders_quartiles[0.75] - murders_quartiles[0.25]

print("\nQuartile Ranges of the 'murders' column:")
print(f"Q1: {murders_quartiles[0.25]}, Q2 (Median): {murders_quartiles[0.5]}, Q3: {murders_quartiles[0.75]}")
print(f"\nInterquartile Range (IQR): {iqr}")
# Out:
# Univariate Analysis:
#
# Central Tendency Measures of the 'murders' column:
# Mean: 7.286915312324292, Median: 1.0, Mode: [0]
#
# Dispersion Measures of the 'murders' column:
# Standard Deviation: 47.217586409131165, Variance: 2229.500466303768
#
# Quartile Ranges of the 'murders' column:
# Q1: 0.0, Q2 (Median): 1.0, Q3: 3.0
#
# Interquartile Range (IQR): 3.0

# %%
print("Univariate Plots:")

# First 30 largest values and draw a bar chart
largest_values = data.nlargest(30, 'murdrate')[['year', 'murdrate']]
plt.figure(figsize=(10, 6))
plt.bar(largest_values['year'].astype(str), largest_values['murdrate'], color='skyblue')
plt.xticks(rotation=90)
plt.title('Top 30 Largest Murder Rates by Year')
plt.xlabel('Year')
plt.ylabel('Murder Rate')
plt.tight_layout()
plt.show()
# Out:
# Univariate Plots:

# %%
# Distribution plot
sns.FacetGrid(data).map(sns.distplot,"murdrate").add_legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.FacetGrid(data).map(sns.distplot,"arrestrate").add_legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.boxplot(x="murdrate",data=data)
plt.show()

# %%
# 1. Histogram
column_name = 'murdrate'
plt.figure(figsize=(8, 5))
plt.hist(data[column_name], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of ' + column_name)
plt.xlabel(column_name)
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Density Plot
column_name = 'murdrate'
plt.figure(figsize=(8, 5))
sns.kdeplot(data[column_name], shade=True, color='red')
plt.title('Density Plot of ' + column_name)
plt.xlabel(column_name)
plt.show()
# Out:
# <ipython-input-53-ebe5341ad47b>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[column_name], shade=True, color='red')

# %%
# 3. Histogram and Density Plot
column_name = 'murdrate'
plt.figure(figsize=(8, 5))
sns.histplot(data[column_name], kde=True, bins=20, color='green')
plt.title('Histogram and Density Plot of ' + column_name)
plt.xlabel(column_name)
plt.ylabel('Frequency')
plt.show()

# %%
# 4. Boxplot
column_name = 'murdrate'
plt.figure(figsize=(5, 8))
sns.boxplot(y=data[column_name], color='orange')
plt.title('Boxplot of ' + column_name)
plt.ylabel(column_name)
plt.show()

# %%
# 5. Vertical Bar Plot
column_name = 'murders'
plt.figure(figsize=(8, 5))
data[column_name].value_counts().plot(kind='bar', color='purple')
plt.title('Vertical Bar Plot of ' + column_name)
plt.xlabel(column_name)
plt.ylabel('Count')
plt.show()

# %%
# 6. Horizontal Bar Plot
column_name = 'countyid'
plt.figure(figsize=(8, 5))
data[column_name].value_counts().plot(kind='barh', color='coral')
plt.title('Horizontal Bar Plot of ' + column_name)
plt.xlabel('Count')
plt.ylabel(column_name)
plt.show()

# %%
# 7. Pie Plot
column_name = 'statefips'
plt.figure(figsize=(7, 7))
data[column_name].value_counts().plot(kind='pie', colors=['gold', 'lightblue', 'pink', 'lightgreen'])
plt.title('Pie Plot of ' + column_name)
plt.ylabel('')
plt.show()

# %%
# 8. Dot Plot
column_name = 'density'
plt.figure(figsize=(8, 5))
plt.plot(data[column_name], 'o', color='blue')
plt.title('Dot Plot of ' + column_name)
plt.xlabel('Index')
plt.ylabel(column_name)
plt.show()

# %% [markdown]
# ---
#
#
#
# *4. Bivariate Analysis and Bivariate Plots*

# %%
# 1. Scatter Plot
plt.scatter(data["murdrate"], data["density"])
plt.title("Scatter Plot for density vs murdrate")
plt.xlabel("density")
plt.ylabel("murdrate")
# Out:
# Text(0, 0.5, 'murdrate')

# %%
# 2. Box Plot
sns.boxplot(x="murders",y="arrests",data=data)
plt.show()

# %%
# 3. Regression Plot
plt.figure(figsize=(10, 6))
sns.regplot(x='popul', y='murdrate', data=data, scatter_kws={'alpha':0.5})
plt.title('Regression Plot: Population vs Murder Rate')
plt.xlabel('Population')
plt.ylabel('Murder Rate')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
# 4. Stacked Bar Plot
exec_counts = data.groupby(['year', 'execs']).size().unstack(fill_value=0)
exec_counts.plot(kind='bar', stacked=True, figsize=(12, 7))
plt.title('Stacked Bar Plot: Executions over Years')
plt.xlabel('Year')
plt.ylabel('Number of Executions')
plt.legend(title='Executions')
plt.ylim(1500, exec_counts.values.max() + 100)
plt.show()

# %% [markdown]
# ---
#
#
#
# *5. Multivariate Analysis and Multivariate Plots*

# %%
# 1. Correlation
corr = stats.pearsonr(data["murdrate"], data["density"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 2.941823910969753e-157
# cor:		 0.13759418870061224

# %%
correlation = data.corr(method='pearson', numeric_only=True)
correlation
# Out:
#              rownames   arrests      countyid   density     popul  perc1019  \
# rownames     1.000000 -0.042613  9.874345e-01  0.002649 -0.060608  0.039989
# arrests     -0.042613  1.000000 -4.606477e-02  0.311693  0.792039 -0.055317
# countyid     0.987434 -0.046065  1.000000e+00  0.010010 -0.061212  0.036127
# density      0.002649  0.311693  1.000971e-02  1.000000  0.380315 -0.135204
# popul       -0.060608  0.792039 -6.121241e-02  0.380315  1.000000 -0.119220
# perc1019     0.039989 -0.055317  3.612727e-02 -0.135204 -0.119220  1.000000
# perc2029    -0.005638  0.097915 -7.710277e-03  0.126121  0.185030  0.256169
# percblack   -0.013782  0.119305 -2.857313e-02  0.129959  0.084739  0.122132
# percmale     0.001813 -0.020348 -1.443695e-03 -0.020912 -0.013728 -0.208278
# rpcincmaint -0.037363  0.143854 -5.677418e-02  0.164865  0.099992  0.098434
# rpcpersinc  -0.051812  0.134136 -4.822934e-02  0.270458  0.331270 -0.462779
# rpcunemins  -0.078843  0.025419 -7.233986e-02  0.034143  0.044673  0.066431
# year         0.000454  0.001588  3.461751e-13  0.003468  0.014997 -0.382645
# murders     -0.039936  0.906295 -4.245941e-02  0.433851  0.877110 -0.073315
# murdrate     0.030421  0.172154  1.384874e-02  0.137594  0.118712  0.046229
# arrestrate   0.021541  0.154936  6.024347e-03  0.061293  0.064519  0.036857
# statefips    0.987121 -0.046130  9.999771e-01  0.009837 -0.060965  0.035966
# countyfips   0.270752 -0.001240  2.318303e-01  0.027039 -0.049541  0.031413
# execs        0.020697  0.083742  1.865559e-02  0.022459  0.160758 -0.019806
# lpopul      -0.046460  0.297718 -3.736177e-02  0.280124  0.557064 -0.078025
# execrate     0.011430 -0.000749  9.194172e-03 -0.000814 -0.003113 -0.011402
#
#              perc2029  percblack  percmale  rpcincmaint  ...  rpcunemins  \
# rownames    -0.005638  -0.013782  0.001813    -0.037363  ...   -0.078843
# arrests      0.097915   0.119305 -0.020348     0.143854  ...    0.025419
# countyid    -0.007710  -0.028573 -0.001444    -0.056774  ...   -0.072340
# density      0.126121   0.129959 -0.020912     0.164865  ...    0.034143
# popul        0.185030   0.084739 -0.013728     0.099992  ...    0.044673
# perc1019     0.256169   0.122132 -0.208278     0.098434  ...    0.066431
# perc2029     1.000000   0.174507 -0.223615    -0.146472  ...    0.032846
# percblack    0.174507   1.000000 -0.104799     0.391590  ...   -0.129342
# percmale    -0.223615  -0.104799  1.000000     0.113756  ...   -0.088569
# rpcincmaint -0.146472   0.391590  0.113756     1.000000  ...    0.189517
# rpcpersinc  -0.006004  -0.130673  0.223476    -0.279905  ...   -0.082969
# rpcunemins   0.032846  -0.129342 -0.088569     0.189517  ...    1.000000
# year        -0.428285   0.011903  0.660332     0.245389  ...   -0.202775
# murders      0.117278   0.139215 -0.025080     0.157738  ...    0.025989
# murdrate     0.074479   0.312546 -0.064556     0.199870  ...   -0.024076
# arrestrate   0.042230   0.227672 -0.037630     0.152835  ...   -0.031012
# statefips   -0.008012  -0.029168 -0.001293    -0.056679  ...   -0.071222
# countyfips   0.041639   0.078872 -0.021957    -0.026596  ...   -0.177052
# execs        0.026597   0.047100  0.028234     0.005941  ...   -0.018663
# lpopul       0.424437   0.148421 -0.082901     0.056256  ...    0.127690
# execrate    -0.011871   0.020806  0.029087     0.007829  ...   -0.014464
#
#                      year   murders  murdrate  arrestrate     statefips  \
# rownames     4.543780e-04 -0.039936  0.030421    0.021541  9.871205e-01
# arrests      1.588388e-03  0.906295  0.172154    0.154936 -4.613004e-02
# countyid     3.461751e-13 -0.042459  0.013849    0.006024  9.999771e-01
# density      3.468035e-03  0.433851  0.137594    0.061293  9.837386e-03
# popul        1.499733e-02  0.877110  0.118712    0.064519 -6.096488e-02
# perc1019    -3.826454e-01 -0.073315  0.046229    0.036857  3.596605e-02
# perc2029    -4.282845e-01  0.117278  0.074479    0.042230 -8.012452e-03
# percblack    1.190266e-02  0.139215  0.312546    0.227672 -2.916773e-02
# percmale     6.603317e-01 -0.025080 -0.064556   -0.037630 -1.293116e-03
# rpcincmaint  2.453886e-01  0.157738  0.199870    0.152835 -5.667931e-02
# rpcpersinc   2.927183e-01  0.170730 -0.035016   -0.040622 -4.823718e-02
# rpcunemins  -2.027755e-01  0.025989 -0.024076   -0.031012 -7.122232e-02
# year         1.000000e+00  0.003815 -0.048111   -0.024852  3.456787e-13
# murders      3.814626e-03  1.000000  0.212655    0.119888 -4.247505e-02
# murdrate    -4.811082e-02  0.212655  1.000000    0.452700  1.318676e-02
# arrestrate  -2.485190e-02  0.119888  0.452700    1.000000  5.461007e-03
# statefips    3.456787e-13 -0.042475  0.013187    0.005461  1.000000e+00
# countyfips   1.496656e-13 -0.007458  0.098245    0.082127  2.252368e-01
# execs        4.452117e-02  0.155903  0.042837    0.017885  1.844054e-02
# lpopul       1.689796e-02  0.343957  0.068035    0.034483 -3.678215e-02
# execrate     3.038773e-02 -0.000010  0.005167    0.004105  9.045622e-03
#
#                countyfips     execs    lpopul  execrate
# rownames     2.707525e-01  0.020697 -0.046460  0.011430
# arrests     -1.239912e-03  0.083742  0.297718 -0.000749
# countyid     2.318303e-01  0.018656 -0.037362  0.009194
# density      2.703860e-02  0.022459  0.280124 -0.000814
# popul       -4.954060e-02  0.160758  0.557064 -0.003113
# perc1019     3.141287e-02 -0.019806 -0.078025 -0.011402
# perc2029     4.163893e-02  0.026597  0.424437 -0.011871
# percblack    7.887198e-02  0.047100  0.148421  0.020806
# percmale    -2.195738e-02  0.028234 -0.082901  0.029087
# rpcincmaint -2.659639e-02  0.005941  0.056256  0.007829
# rpcpersinc  -9.890684e-03  0.050651  0.376327 -0.000379
# rpcunemins  -1.770517e-01 -0.018663  0.127690 -0.014464
# year         1.496656e-13  0.044521  0.016898  0.030388
# murders     -7.457649e-03  0.155903  0.343957 -0.000010
# murdrate     9.824459e-02  0.042837  0.068035  0.005167
# arrestrate   8.212719e-02  0.017885  0.034483  0.004105
# statefips    2.252368e-01  0.018441 -0.036782  0.009046
# countyfips   1.000000e+00  0.035151 -0.091789  0.023437
# execs        3.515088e-02  1.000000  0.096420  0.350218
# lpopul      -9.178859e-02  0.096420  1.000000 -0.009481
# execrate     2.343731e-02  0.350218 -0.009481  1.000000
#
# [21 rows x 21 columns]

# %%
# 2. Correlation Matrix
correlation_matrix = data[['arrests', 'murders', 'murdrate', 'arrestrate', 'popul', 'density']].corr()
print(correlation_matrix)
# Out:
#              arrests   murders  murdrate  arrestrate     popul   density
# arrests     1.000000  0.906295  0.172154    0.154936  0.792039  0.311693
# murders     0.906295  1.000000  0.212655    0.119888  0.877110  0.433851
# murdrate    0.172154  0.212655  1.000000    0.452700  0.118712  0.137594
# arrestrate  0.154936  0.119888  0.452700    1.000000  0.064519  0.061293
# popul       0.792039  0.877110  0.118712    0.064519  1.000000  0.380315
# density     0.311693  0.433851  0.137594    0.061293  0.380315  1.000000

# %%
# 3. Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# 4. Pair Plot
sns.pairplot(data[['arrests', 'murders', 'murdrate', 'arrestrate', 'popul', 'density']])
plt.suptitle('Pair Plot of Selected Variables', y=1.02)
plt.show()

# %% [markdown]
# ---
#
#
#
# *6. Time Series Analysis*

# %%
# Random numpy generated time series

zero_mean_series = np.random.normal(loc=0.0, scale=1., size=50)
zero_mean_series
# Out:
# array([ 2.2795778 ,  0.82072794, -0.76506084,  0.00555   ,  0.20953871,
#        -0.23163464, -2.0063879 , -0.01854578, -1.32106373, -0.15791283,
#         0.53186025, -0.88678541,  0.06918401,  0.30781583, -0.31239416,
#         0.44178848,  1.12371646,  1.1392148 , -1.03819499,  0.56312018,
#        -0.57855537,  0.18995536,  1.25539253,  1.09024813,  3.03708545,
#         0.42335716,  1.35978605, -1.79787609,  1.42513386, -0.65618368,
#        -1.12101944,  1.55803612, -1.46002499,  0.12973914,  1.00041922,
#        -0.03636803,  0.45343091,  0.93755957, -1.66128562,  0.36039913,
#         0.88017548, -0.79887302,  0.77171106, -0.84745307,  2.36401629,
#         0.47584129, -0.17773032,  0.41925893,  1.47281888,  0.27027121])

# %%
plt.figure(figsize=(16, 8))
g = sns.lineplot(data=zero_mean_series)
g.set_title('Zero mean model')
g.set_xlabel('Time index')
plt.show()

# %%
random_walk = np.cumsum(zero_mean_series)
random_walk
# Out:
# array([ 2.2795778 ,  3.10030574,  2.33524491,  2.3407949 ,  2.55033362,
#         2.31869898,  0.31231108,  0.29376529, -1.02729844, -1.18521127,
#        -0.65335102, -1.54013643, -1.47095242, -1.16313659, -1.47553075,
#        -1.03374227,  0.08997419,  1.22918899,  0.19099401,  0.75411419,
#         0.17555881,  0.36551417,  1.6209067 ,  2.71115483,  5.74824028,
#         6.17159744,  7.5313835 ,  5.73350741,  7.15864126,  6.50245758,
#         5.38143814,  6.93947425,  5.47944927,  5.60918841,  6.60960763,
#         6.5732396 ,  7.02667051,  7.96423008,  6.30294447,  6.6633436 ,
#         7.54351908,  6.74464606,  7.51635712,  6.66890405,  9.03292034,
#         9.50876162,  9.3310313 ,  9.75029023, 11.22310911, 11.49338032])

# %%
plt.figure(figsize=(16, 8))
g = sns.lineplot(data=random_walk)
g.set_title('Random Walk')
g.set_xlabel('Time index')
plt.show()

# %%
# Dataset time series

df = pd.read_csv('https://raw.githubusercontent.com/salemprakash/EDA/main/Data/countymurders.csv')
df.columns
# Out:
# Index(['rownames', 'arrests', 'countyid', 'density', 'popul', 'perc1019',
#        'perc2029', 'percblack', 'percmale', 'rpcincmaint', 'rpcpersinc',
#        'rpcunemins', 'year', 'murders', 'murdrate', 'arrestrate', 'statefips',
#        'countyfips', 'execs', 'lpopul', 'execrate'],
#       dtype='object')

# %%
# Data Cleaning
df.shape
# Out:
# (37349, 21)

# %%
df.tail(10)
# Out:
#        rownames  arrests  countyid   density  popul  perc1019   perc2029  \
# 37339     37340      0.0     56045  3.030000   7254  15.56000  12.310000
# 37340     37341      0.0     56045  2.850000   6842  15.54000  11.590000
# 37341     37342      0.0     56045  2.780000   6676  15.69000  10.950000
# 37342     37343      0.0     56045  2.750000   6591  15.93000  10.730000
# 37343     37344      0.0     56045  2.710000   6507  16.15000  10.480000
# 37344     37345      0.0     56045  2.680000   6430  16.35000  10.260000
# 37345     37346      1.0     56045  2.708031   6493  16.67950   9.610350
# 37346     37347      0.0     56045  2.736391   6561  16.79622   9.510745
# 37347     37348      0.0     56045  2.730135   6546  17.01803   9.563092
# 37348     37349      0.0     56045  2.733472   6554  16.90571   9.642966
#
#        percblack  percmale  rpcincmaint  ...  rpcunemins  year  murders  \
# 37339   0.070000  41.01000       73.040  ...      66.880  1987        0
# 37340   0.060000  41.26000       82.910  ...      44.840  1988        0
# 37341   0.060000  41.65000       83.120  ...      42.770  1989        0
# 37342   0.060000  42.01000       76.600  ...      34.470  1990        0
# 37343   0.060000  42.35000       86.610  ...      41.100  1991        0
# 37344   0.060000  42.67000       95.540  ...      54.190  1992        0
# 37345   0.077006  50.13091      107.260  ...      42.904  1993        0
# 37346   0.030483  50.16004       98.550  ...      39.150  1994        0
# 37347   0.076383  50.18332      106.928  ...      38.048  1995        0
# 37348   0.076289  50.13732      116.116  ...      40.194  1996        0
#
#        murdrate  arrestrate  statefips  countyfips  execs    lpopul  execrate
# 37339       0.0     0.00000         56          45      0  8.889308       0.0
# 37340       0.0     0.00000         56          45      0  8.830835       0.0
# 37341       0.0     0.00000         56          45      0  8.806274       0.0
# 37342       0.0     0.00000         56          45      0  8.793460       0.0
# 37343       0.0     0.00000         56          45      0  8.780634       0.0
# 37344       0.0     0.00000         56          45      0  8.768730       0.0
# 37345       0.0     1.54012         56          45      0  8.778480       0.0
# 37346       0.0     0.00000         56          45      0  8.788898       0.0
# 37347       0.0     0.00000         56          45      0  8.786610       0.0
# 37348       0.0     0.00000         56          45      0  8.787830       0.0
#
# [10 rows x 21 columns]

# %%
df.dtypes
# Out:
# rownames         int64
# arrests        float64
# countyid         int64
# density        float64
# popul            int64
# perc1019       float64
# perc2029       float64
# percblack      float64
# percmale       float64
# rpcincmaint    float64
# rpcpersinc     float64
# rpcunemins     float64
# year             int64
# murders          int64
# murdrate       float64
# arrestrate     float64
# statefips        int64
# countyfips       int64
# execs            int64
# lpopul         float64
# execrate       float64
# dtype: object

# %%
df.tail(3)
# Out:
#       rownames  arrests  countyid   density  popul  perc1019  perc2029  \
# year
# 1994     37347      0.0     56045  2.736391   6561  16.79622  9.510745
# 1995     37348      0.0     56045  2.730135   6546  17.01803  9.563092
# 1996     37349      0.0     56045  2.733472   6554  16.90571  9.642966
#
#       percblack  percmale  rpcincmaint  rpcpersinc  rpcunemins  murders  \
# year
# 1994   0.030483  50.16004       98.550    13463.55      39.150        0
# 1995   0.076383  50.18332      106.928    13489.33      38.048        0
# 1996   0.076289  50.13732      116.116    13198.94      40.194        0
#
#       murdrate  arrestrate  statefips  countyfips  execs    lpopul  execrate
# year
# 1994       0.0         0.0         56          45      0  8.788898       0.0
# 1995       0.0         0.0         56          45      0  8.786610       0.0
# 1996       0.0         0.0         56          45      0  8.787830       0.0

# %%
df.index
# Out:
# Index([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        ...
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996],
#       dtype='int64', name='year', length=37349)

# %%
df.sample(5, random_state=0)
# Out:
#       rownames  arrests  countyid  density   popul  perc1019  perc2029  \
# year
# 1984      5020      0.0     16051    14.79   16192     18.73     14.35
# 1986     28006      4.0     48049    36.72   34656     15.71     14.72
# 1990      1524      8.0      5041    21.99   16820     17.36     13.29
# 1983      3166      9.0      6089    32.44  122800     15.77     15.32
# 1990      1949      4.0      5091    61.98   38680     15.98     14.41
#
#       percblack  percmale  rpcincmaint  rpcpersinc  rpcunemins  murders  \
# year
# 1984       0.06     38.38        49.01     7717.79       62.46        0
# 1986       4.62     40.70       103.17    10324.20       69.39        3
# 1990      42.87     38.07       293.38     8422.93       55.15        3
# 1983       0.67     41.32       344.03    10723.07      152.46        8
# 1990      22.76     39.87       193.80     9492.27       23.75        3
#
#       murdrate  arrestrate  statefips  countyfips  execs     lpopul  execrate
# year
# 1984  0.000000    0.000000         16          51      0   9.692272       0.0
# 1986  0.865651    1.154201         48          49      0  10.453230       0.0
# 1990  1.783591    4.756243          5          41      0   9.730324       0.0
# 1983  0.651466    0.732899          6          89      0  11.718310       0.0
# 1990  0.775595    1.034126          5          91      0  10.563080       0.0

# %%
df.loc[1980]
# Out:
#       rownames  arrests  countyid  density  popul  perc1019  perc2029  \
# year
# 1980         1      2.0      1001    54.05  32216     20.63     15.28
# 1980        18      4.0      1003    49.45  78944     17.98     14.95
# 1980        35      2.0      1005    27.95  24736     19.13     14.10
# 1980        52      2.0      1009    56.59  36536     17.88     14.94
# 1980        69      1.0      1011    16.96  10600     19.14     14.58
# ...        ...      ...       ...      ...    ...       ...       ...
# 1980     37265      9.0     56037     4.05  42272     16.11     23.31
# 1980     37282      0.0     56039     2.37   9494     13.92     27.82
# 1980     37299      0.0     56041     6.57  13684     16.74     22.08
# 1980     37316      0.0     56043     4.28   9590     18.34     17.07
# 1980     37333      1.0     56045     3.00   7193     16.96     18.53
#
#       percblack  percmale  rpcincmaint  rpcpersinc  rpcunemins  murders  \
# year
# 1980      22.33     40.25       167.67     8780.80       29.16        2
# 1980      15.22     40.55       132.43     9317.83       25.51        4
# 1980      44.36     38.44       304.96     7535.43       72.90        2
# 1980       1.64     41.83       145.80     8011.71       48.60        4
# 1980      67.65     37.59       443.47     6522.12       86.26        1
# ...         ...       ...          ...         ...         ...      ...
# 1980       0.77     41.89        32.80    15187.50       44.95        7
# 1980       0.04     45.32        27.94    17226.27      138.51        0
# 1980       0.13     40.81        30.38    11292.20       24.30        0
# 1980       0.10     42.16        78.97    12335.89       24.30        0
# 1980       0.08     41.43        49.81    13002.93       32.80        1
#
#       murdrate  arrestrate  statefips  countyfips  execs     lpopul  execrate
# year
# 1980  0.620810    0.620810          1           1      0  10.380220       0.0
# 1980  0.506688    0.506688          1           3      0  11.276490       0.0
# 1980  0.808538    0.808538          1           5      0  10.116010       0.0
# 1980  1.094811    0.547405          1           9      0  10.506050       0.0
# 1980  0.943396    0.943396          1          11      0   9.268609       0.0
# ...        ...         ...        ...         ...    ...        ...       ...
# 1980  1.655942    2.129069         56          37      0  10.651880       0.0
# 1980  0.000000    0.000000         56          39      0   9.158415       0.0
# 1980  0.000000    0.000000         56          41      0   9.523983       0.0
# 1980  0.000000    0.000000         56          43      0   9.168476       0.0
# 1980  1.390241    1.390241         56          45      0   8.880863       0.0
#
# [2197 rows x 20 columns]

# %%
sns.set(rc={'figure.figsize':(11, 4)})
plt.rcParams['figure.figsize'] = (8,5)
plt.rcParams['figure.dpi'] = 150
sns.lineplot(data=df['murders'])
# Out:
# <Axes: xlabel='year', ylabel='murders'>

# %%
df['murders'].plot(linewidth=0.5)
# Out:
# <Axes: xlabel='year'>

# %%
plt.figure(figsize=(16, 8))
g = sns.lineplot(data=data)
g.set_title('County murders')
g.set_xlabel('Time index')
plt.show()

# %%
random_walk = np.cumsum(data)
plt.figure(figsize=(16, 8))
g = sns.lineplot(data=random_walk)
g.set_title('Random Walk')
g.set_xlabel('Time index')
plt.show()

# %%
cols_to_plot = ['murders', 'arrests']
axes = df[cols_to_plot].plot(marker='.', alpha=0.5,
linestyle='None',figsize=(14, 6), subplots=True)
for ax in axes:
    ax.set_ylabel('Values')

# %% [markdown]
# # page 12 (book)

# %%
ax = df.loc['1980', 'murders'].plot()
ax.set_ylabel('Murders')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '1980'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-492107042c9b> in <cell line: 1>()
# ----> 1 ax = df.loc['1980', 'murders'].plot()
#       2 ax.set_ylabel('Murders')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1145             if self._is_scalar_access(key):
#    1146                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147             return self._getitem_tuple(key)
#    1148         else:
#    1149             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1328         with suppress(IndexingError):
#    1329             tup = self._expand_ellipsis(tup)
# -> 1330             return self._getitem_lowerdim(tup)
#    1331
#    1332         # no multi-index, so validate all of the indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1037                 # We don't need to check for tuples here because those are
#    1038                 #  caught by the _is_nested_tuple_indexer check above.
# -> 1039                 section = self._getitem_axis(key, axis=i)
#    1040
#    1041                 # We should never have a scalar section here, because
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1391         # fall thru to straight lookup
#    1392         self._validate_key(key, axis)
# -> 1393         return self._get_label(key, axis=axis)
#    1394
#    1395     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1341     def _get_label(self, label, axis: AxisInt):
#    1342         # GH#5567 this will fail if the label is not present in the axis.
# -> 1343         return self.obj.xs(label, axis=axis)
#    1344
#    1345     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4234                     new_index = index[loc]
#    4235         else:
# -> 4236             loc = index.get_loc(key)
#    4237
#    4238             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '1980'

# %%
ax = df.loc['1980', 'murders'].plot(marker = 'o', linestyle = '-')
ax.set_ylabel('Murders')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '1980'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-155-aebb79da8db3> in <cell line: 1>()
# ----> 1 ax = df.loc['1980', 'murders'].plot(marker = 'o', linestyle = '-')
#       2 ax.set_ylabel('Murders')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1145             if self._is_scalar_access(key):
#    1146                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147             return self._getitem_tuple(key)
#    1148         else:
#    1149             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1328         with suppress(IndexingError):
#    1329             tup = self._expand_ellipsis(tup)
# -> 1330             return self._getitem_lowerdim(tup)
#    1331
#    1332         # no multi-index, so validate all of the indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1037                 # We don't need to check for tuples here because those are
#    1038                 #  caught by the _is_nested_tuple_indexer check above.
# -> 1039                 section = self._getitem_axis(key, axis=i)
#    1040
#    1041                 # We should never have a scalar section here, because
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1391         # fall thru to straight lookup
#    1392         self._validate_key(key, axis)
# -> 1393         return self._get_label(key, axis=axis)
#    1394
#    1395     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1341     def _get_label(self, label, axis: AxisInt):
#    1342         # GH#5567 this will fail if the label is not present in the axis.
# -> 1343         return self.obj.xs(label, axis=axis)
#    1344
#    1345     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4234                     new_index = index[loc]
#    4235         else:
# -> 4236             loc = index.get_loc(key)
#    4237
#    4238             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '1980'

# %%
ax = df.loc['1980':'1990', 'murders'].plot(marker = 'o', linestyle = '-')
ax.set_ylabel('Murders')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '1980'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-157-3571ef1021ea> in <cell line: 1>()
# ----> 1 ax = df.loc['1980':'1990', 'murders'].plot(marker = 'o', linestyle = '-')
#       2 ax.set_ylabel('Murders')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1145             if self._is_scalar_access(key):
#    1146                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147             return self._getitem_tuple(key)
#    1148         else:
#    1149             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1328         with suppress(IndexingError):
#    1329             tup = self._expand_ellipsis(tup)
# -> 1330             return self._getitem_lowerdim(tup)
#    1331
#    1332         # no multi-index, so validate all of the indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1061                     return section
#    1062                 # This is an elided recursive call to iloc/loc
# -> 1063                 return getattr(section, self.name)[new_key]
#    1064
#    1065         raise IndexingError("not applicable")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1151
#    1152             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153             return self._getitem_axis(maybe_callable, axis=axis)
#    1154
#    1155     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1371         if isinstance(key, slice):
#    1372             self._validate_key(key, axis)
# -> 1373             return self._get_slice_axis(key, axis=axis)
#    1374         elif com.is_bool_indexer(key):
#    1375             return self._getbool_axis(key, axis=axis)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1403
#    1404         labels = obj._get_axis(axis)
# -> 1405         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1406
#    1407         if isinstance(indexer, slice):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step)
#    6600         slice(1, 3, None)
#    6601         """
# -> 6602         start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6603
#    6604         # return a slice
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step)
#    6817         start_slice = None
#    6818         if start is not None:
# -> 6819             start_slice = self.get_slice_bound(start, "left")
#    6820         if start_slice is None:
#    6821             start_slice = 0
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side)
#    6742             except ValueError:
#    6743                 # raise the original KeyError
# -> 6744                 raise err
#    6745
#    6746         if isinstance(slc, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side)
#    6736         # we need to look up the label
#    6737         try:
# -> 6738             slc = self.get_loc(label)
#    6739         except KeyError as err:
#    6740             try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '1980'
